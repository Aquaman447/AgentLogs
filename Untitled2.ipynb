# %%
import pandas as pd

# %%
df1=pd.read_csv("EmpInfo.csv")
df1
# Out:
#        EMPID  Gender  HourlyRate                    JobRole MaritalStatus
# 0     E00001  Female          94            Sales Executive        Single
# 1     E00002    Male          61         Research Scientist       Married
# 2     E00003    Male          92      Laboratory Technician        Single
# 3     E00004  Female          56         Research Scientist       Married
# 4     E00005    Male          40      Laboratory Technician       Married
# ...      ...     ...         ...                        ...           ...
# 1053  E01054    Male          93         Research Scientist       Married
# 1054  E01055    Male          35  Healthcare Representative      Divorced
# 1055  E01056    Male          71          Research Director      Divorced
# 1056  E01057    Male          92       Sales Representative       Married
# 1057  E01058  Female          51            Sales Executive        Single
#
# [1058 rows x 5 columns]

# %%
df2=pd.read_csv("EmpSalDetails.csv")
df2
# Out:
#        EMPID    EducationField                    JobRole  MonthlyRate  \
# 0     E00001     Life Sciences            Sales Executive        19479
# 1     E00002     Life Sciences         Research Scientist        24907
# 2     E00003             Other      Laboratory Technician         2396
# 3     E00004     Life Sciences         Research Scientist        23159
# 4     E00005           Medical      Laboratory Technician        16632
# ...      ...               ...                        ...          ...
# 1053  E01054     Life Sciences         Research Scientist         2721
# 1054  E01055     Life Sciences  Healthcare Representative        20948
# 1055  E01056           Medical          Research Director        11929
# 1056  E01057  Technical Degree       Sales Representative        15747
# 1057  E01058  Technical Degree            Sales Executive        17485
#
#       YearsAtCompany
# 0                  6
# 1                 10
# 2                  0
# 3                  8
# ...

# %%
finaldf=pd.merge(df1,df2)
finaldf
# Out:
#        EMPID  Gender  HourlyRate                    JobRole MaritalStatus  \
# 0     E00001  Female          94            Sales Executive        Single
# 1     E00002    Male          61         Research Scientist       Married
# 2     E00003    Male          92      Laboratory Technician        Single
# 3     E00004  Female          56         Research Scientist       Married
# 4     E00005    Male          40      Laboratory Technician       Married
# ...      ...     ...         ...                        ...           ...
# 1053  E01054    Male          93         Research Scientist       Married
# 1054  E01055    Male          35  Healthcare Representative      Divorced
# 1055  E01056    Male          71          Research Director      Divorced
# 1056  E01057    Male          92       Sales Representative       Married
# 1057  E01058  Female          51            Sales Executive        Single
#
#         EducationField  MonthlyRate  YearsAtCompany
# ...

# %%
finaldf.sort_values('MonthlyRate',ascending=False)
# Out:
#       EMPID  Gender  HourlyRate                    JobRole MaritalStatus  \
# 513  E00514    Male          32         Research Scientist        Single
# 808  E00809  Female          93         Research Scientist      Divorced
# 107  E00108    Male          46            Sales Executive        Single
# 859  E00860  Female          69         Research Scientist       Married
# 386  E00387  Female          95      Laboratory Technician      Divorced
# ..      ...     ...         ...                        ...           ...
# 178  E00179  Female          92            Sales Executive      Divorced
# 473  E00474    Male          58          Research Director      Divorced
# 459  E00460  Female          62  Healthcare Representative        Single
# 543  E00544    Male          49      Laboratory Technician        Single
# 28   E00029  Female          42  Healthcare Representative       Married
#
#     EducationField  MonthlyRate  YearsAtCompany
# ...
