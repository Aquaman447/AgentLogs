# %%
import pandas as pd

# %%
df1=pd.read_csv("diabetes.csv")
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1.shape
# Out:
# (768, 9)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df1['Age'].mean()
# Out:
# 33.240885416666664

# %%
df1.memory_usage(deep=True)
# Out:
# Index                         80
# Pregnancies                 6144
# Glucose                     6144
# BloodPressure               6144
# SkinThickness               6144
# Insulin                     6144
# BMI                         6144
# DiabetesPedigreeFunction    6144
# Age                         6144
# Outcome                     6144
# dtype: int64

# %%
df1['BMI'].value_counts()
# Out:
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 33.3    10
# 32.4    10
# 32.8     9
# 30.8     9
# 32.9     9
# 30.1     9
# 29.7     8
# 33.6     8
# 34.2     8
# 30.4     7
# 35.5     7
# 27.6     7
# 33.2     7
# 28.7     7
# 25.9     7
# 39.4     7
# 30.0     7
# 30.5     7
# 27.8     7
# 25.2     6
# 36.8     6
# 28.9     6
# 34.9     6
# 24.2     6
# 34.3     6
# 38.5     6
#         ..
# 21.7     1
# 21.2     1
# 43.1     1
# 45.4     1
# 40.7     1
# 45.2     1
# 24.1     1
# 44.1     1
# 29.2     1
# 38.6     1
# 67.1     1
# 41.2     1
# 26.7     1
# 48.8     1
# 49.6     1
# 46.7     1
# 41.8     1
# 22.7     1
# 24.9     1
# 40.8     1
# 57.3     1
# 31.1     1
# 53.2     1
# 46.3     1
# 36.2     1
# 32.1     1
# 52.9     1
# 31.3     1
# 45.7     1
# 42.8     1
# Name: BMI, Length: 248, dtype: int64

# %%
df1.groupby(by='Age').Glucose.mean()
# Out:
# Age
# 21    108.317460
# 22    108.208333
# 23    111.578947
# 24    117.891304
# 25    110.083333
# 26    118.212121
# 27    115.281250
# 28    119.914286
# 29    127.379310
# 30    122.285714
# 31    126.958333
# 32    116.312500
# 33    122.882353
# 34    131.857143
# 35    121.400000
# 36    132.437500
# 37    130.157895
# 38    121.125000
# 39    126.750000
# 40    130.923077
# 41    129.090909
# 42    109.555556
# 43    133.000000
# 44    124.375000
# 45    131.200000
# 46    105.923077
# 47    137.000000
# 48    107.600000
# 49    153.000000
# 50    138.250000
# 51    147.625000
# 52    133.000000
# 53    158.000000
# 54    140.333333
# 55    140.750000
# 56     98.333333
# 57    137.800000
# 58    135.142857
# 59    173.333333
# 60    146.400000
# 61    144.000000
# 62    139.500000
# 63    133.250000
# 64    120.000000
# 65    137.000000
# 66    157.000000
# 67    132.333333
# 68     91.000000
# 69    134.000000
# 70    145.000000
# 72    119.000000
# 81    134.000000
# ...

# %%
df1.sort_values('Insulin',ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 13             1      189             60             23      846  30.1
# 228            4      197             70             39      744  36.7
# 247            0      165             90             33      680  52.3
# 584            8      124             76             24      600  28.7
# 409            1      172             68             49      579  42.4
# 286            5      155             84             44      545  38.7
# 8              2      197             70             45      543  30.5
# 655            2      155             52             27      540  38.7
# 753            0      181             88             44      510  43.3
# 186            8      181             68             36      495  30.1
# 111            8      155             62             26      495  34.0
# 153            1      153             82             42      485  40.6
# ...

# %%
df1['Outcome'].min()
# Out:
# 0

# %%
df1['DiabetesPedigreeFunction'].var()
# Out:
# 0.10977863787313938

# %%
df1['SkinThickness'].std()
# Out:
# 15.952217567727677

# %%
df1['Pregnancies'].mode()
# Out:
# 0    1
# dtype: int64

# %%
print(type(df1.Outcome))
# Out:
# <class 'pandas.core.series.Series'>

# %%
type(df1.Age)
# Out:
# pandas.core.series.Series

# %%
df1['Outcome'].replace(0,9)
# Out:
# 0      1
# 1      9
# 2      1
# 3      9
# 4      1
# 5      9
# 6      1
# 7      9
# 8      1
# 9      1
# 10     9
# 11     1
# 12     9
# 13     1
# 14     1
# 15     1
# 16     1
# 17     1
# 18     9
# 19     1
# 20     9
# 21     9
# 22     1
# 23     1
# 24     1
# 25     1
# 26     1
# 27     9
# 28     9
# 29     9
#       ..
# 738    9
# 739    1
# 740    1
# 741    9
# 742    9
# 743    1
# 744    9
# 745    9
# 746    1
# 747    9
# 748    1
# 749    1
# 750    1
# 751    9
# 752    9
# 753    1
# 754    1
# 755    1
# 756    9
# 757    1
# 758    9
# 759    1
# 760    9
# 761    1
# 762    9
# 763    9
# 764    9
# 765    9
# 766    1
# 767    9
# Name: Outcome, Length: 768, dtype: int64

# %%
df1['Age'].mean()
# Out:
# 33.240885416666664

# %%
df=pd.read_csv("employee_data.csv")
df
# Out:
#      Unnamed: 0   id groups  age  healthy_eating  active_lifestyle  salary
# 0             0    0      A   36               5                 5    2297
# 1             1    1      A   55               3                 5    1134
# 2             2    2      A   61               8                 1    4969
# 3             3    3      O   29               3                 6     902
# 4             4    4      O   34               6                 2    3574
# 5             5    5      O   42               5                 3    2761
# 6             6    6     AB   53               4                 6    1484
# 7             7    7      B   41               8                 6    3809
# 8             8    8      A   47               5                 6    2065
# 9             9    9      A   31               4                 8    1020
# 10           10   10      A   47               6                 9    1950
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.set_index(['id'],drop=True,inplace=True)
df.head()
# Out:
#    groups  age  healthy_eating  active_lifestyle  salary
# id
# 0       A   36               5                 5    2297
# 1       A   55               3                 5    1134
# 2       A   61               8                 1    4969
# 3       O   29               3                 6     902
# 4       O   34               6                 2    3574

# %%
df.drop(['groups'],axis=1).head()
# Out:
#     age  healthy_eating  active_lifestyle  salary
# id
# 0    36               5                 5    2297
# 1    55               3                 5    1134
# 2    61               8                 1    4969
# 3    29               3                 6     902
# 4    34               6                 2    3574

# %%
df.reset_index().head()
df.index.name = 'ROLL NO'
df.head()
# Out:
#         groups  age  healthy_eating  active_lifestyle  salary
# ROLL NO
# 0            A   36               5                 5    2297
# 1            A   55               3                 5    1134
# 2            A   61               8                 1    4969
# 3            O   29               3                 6     902
# 4            O   34               6                 2    3574

# %%
df.head()
# Out:
#         groups  age  healthy_eating  active_lifestyle  salary
# ROLL NO
# 0            A   36               5                 5    2297
# 1            A   55               3                 5    1134
# 2            A   61               8                 1    4969
# 3            O   29               3                 6     902
# 4            O   34               6                 2    3574

# %%
df.head()
# Out:
#         groups  age  healthy_eating  active_lifestyle  salary
# ROLL NO
# 0            A   36               5                 5    2297
# 1            A   55               3                 5    1134
# 2            A   61               8                 1    4969
# 3            O   29               3                 6     902
# 4            O   34               6                 2    3574

# %%
df.sort_values(by='age',ascending=False,inplace=True)
df.head()
# Out:
#         groups  age  healthy_eating  active_lifestyle  salary
# ROLL NO
# 999          B   64               4                 9     788
# 913          A   64               6                 5    2878
# 706          A   64               2                 3    1017
# 701          O   64               6                 5    2878
# 422         AB   64               4                 7    1252

# %%
df.sort_index(axis=1).head()
# Out:
#          active_lifestyle  age groups  healthy_eating  salary
# ROLL NO
# 999                     9   64      B               4     788
# 913                     5   64      A               6    2878
# 706                     3   64      A               2    1017
# 701                     5   64      O               6    2878
# 422                     7   64     AB               4    1252

# %%
df2=df.copy()

# %%
df2.sort_values('salary',inplace=True)
df2.head()
# Out:
#         groups  age  healthy_eating  active_lifestyle  salary
# ROLL NO
# 574         AB   23               2                 5     553
# 721          A   62               2                 5     553
# 611          O   43               2                 5     553
# 927          B   56               2                 5     553
# 468          O   35               2                 5     553

# %%
df.cumsum(axis=0)
#extra
# Out:
#                                                     groups    age  \
# ROLL NO
# 999                                                      B     64
# 913                                                     BA    128
# 706                                                    BAA    192
# 701                                                   BAAO    256
# 422                                                 BAAOAB    320
# 245                                                BAAOABO    384
# 443                                               BAAOABOO    448
# 234                                              BAAOABOOA    512
# 508                                             BAAOABOOAO    576
# 60                                             BAAOABOOAOO    640
# 974                                          BAAOABOOAOOAB    704
# 920                                         BAAOABOOAOOABA    768
# 54                                        BAAOABOOAOOABAAB    832
# ...

# %%
boxplot=df.boxplot(column=['age','salary','healthy_eating','active_lifestyle'])
#extras

# %%
df.describe()
# Out:
#                age  healthy_eating  active_lifestyle      salary
# count  1000.000000     1000.000000       1000.000000  1000.00000
# mean     41.155000        4.944000          5.683000  2227.46100
# std      13.462995        2.013186          2.048587  1080.20976
# min      18.000000        0.000000          0.000000   553.00000
# 25%      30.000000        4.000000          4.000000  1360.00000
# 50%      41.000000        5.000000          6.000000  2174.00000
# 75%      53.000000        6.000000          7.000000  2993.75000
# max      64.000000       10.000000         10.000000  5550.00000

# %%
df.all(axis=0)
#extras
# Out:
# groups               True
# age                  True
# healthy_eating      False
# active_lifestyle    False
# salary               True
# dtype: bool
